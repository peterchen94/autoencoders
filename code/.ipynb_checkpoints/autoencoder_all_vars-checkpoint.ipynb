# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import Input,Dense, Dropout
from keras.models import Model,Sequential
from sklearn.metrics import roc_curve, auc
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score,adjusted_rand_score,v_measure_score, completeness_score, homogeneity_score, silhouette_score,roc_curve, auc, f1_score, precision_recall_curve, precision_score,recall_score,accuracy_score,confusion_matrix
from utils import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Link to Paper

# %% [markdown]
# https://arxiv.org/pdf/1809.10717.pdf

# %%
DATA_DIR = '/Users/PeterC/Documents/gt/practicum/autoencoders/data/'
DATA_DIR = '/Users/chenpete/Documents/ESP/practicum/autoencoders/data/'

non_scale_cols = ['time','y_early','y_rank','y_count','y']
param_cols = [
        'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
       'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19',
       'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29',
       'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39',
       'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49',
       'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58', 'x59',
       'x60','x61']

y_col = 'y_early'
early_step = 4

df = pd.read_csv(DATA_DIR + 'paper_mill_rare_events.csv')
df['time'] = pd.to_datetime(df['time'])
X_train, X_test, y_train, y_test,y_rank_train, y_rank_test,y_count_train, y_count_test = preprocess_paper_mill_data(df,param_cols,y_col, non_scale_cols,early_step)

# %% [markdown]
# # Model 1: Layer autoencoder

# %%
model = simple_ann_autoencoder_regression(param_cols)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6276a71c7ae3> in <module>
# ----> 1 model = simple_ann_autoencoder_regression()
#       2 model.summary()
#
# ~/Documents/ESP/practicum/autoencoders/code/utils.py in simple_ann_autoencoder_regression()
#      26 def simple_ann_autoencoder_regression():
#      27     model = Sequential()
# ---> 28     model.add(Dense(units = 32,activation='relu',input_shape = (len(param_cols),)))
#      29     model.add(Dense(units = 16,activation='relu'))
#      30     model.add(Dense(units = 32,activation='relu'))
#
# NameError: name 'param_cols' is not defined

# %%
history_callback = model.fit(X_train,X_train,epochs=30,batch_size = 12)
loss_history = history_callback.history['loss']
# Out:
# Epoch 1/30
# 16007/16007 [==============================] - 1s 81us/step - loss: 0.3693
# Epoch 2/30
# 16007/16007 [==============================] - 1s 67us/step - loss: 0.1989
# Epoch 3/30
# 16007/16007 [==============================] - 1s 68us/step - loss: 0.1621
# Epoch 4/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.1433
# Epoch 5/30
# 16007/16007 [==============================] - 1s 67us/step - loss: 0.1315
# Epoch 6/30
# 16007/16007 [==============================] - 1s 67us/step - loss: 0.1225
# Epoch 7/30
# 16007/16007 [==============================] - 1s 68us/step - loss: 0.1153
# Epoch 8/30
# 16007/16007 [==============================] - 1s 67us/step - loss: 0.1099
# Epoch 9/30
# 16007/16007 [==============================] - 1s 67us/step - loss: 0.1054
# Epoch 10/30
# 16007/16007 [==============================] - 1s 68us/step - loss: 0.1023
# Epoch 11/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0996
# Epoch 12/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0971
# Epoch 13/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0953
# Epoch 14/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0936
# Epoch 15/30
# 16007/16007 [==============================] - 1s 70us/step - loss: 0.0924
# Epoch 16/30
# 16007/16007 [==============================] - 1s 72us/step - loss: 0.0914
# Epoch 17/30
# 16007/16007 [==============================] - 1s 74us/step - loss: 0.0901
# Epoch 18/30
# 16007/16007 [==============================] - 1s 71us/step - loss: 0.0894
# Epoch 19/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0886
# Epoch 20/30
# 16007/16007 [==============================] - 1s 73us/step - loss: 0.0879
# Epoch 21/30
# 16007/16007 [==============================] - 1s 76us/step - loss: 0.0869
# Epoch 22/30
# 16007/16007 [==============================] - 1s 76us/step - loss: 0.0865
# Epoch 23/30
# 16007/16007 [==============================] - 1s 76us/step - loss: 0.0862
# Epoch 24/30
# 16007/16007 [==============================] - 1s 77us/step - loss: 0.0854
# Epoch 25/30
# 16007/16007 [==============================] - 1s 75us/step - loss: 0.0850
# Epoch 26/30
# 16007/16007 [==============================] - 1s 76us/step - loss: 0.0847
# Epoch 27/30
# 16007/16007 [==============================] - 1s 70us/step - loss: 0.0840
# Epoch 28/30
# 16007/16007 [==============================] - 1s 68us/step - loss: 0.0835
# Epoch 29/30
# 16007/16007 [==============================] - 1s 68us/step - loss: 0.0832
# Epoch 30/30
# 16007/16007 [==============================] - 1s 69us/step - loss: 0.0829

# %%
model.save('autoencoder_32_16_32.h5')

# %%
plt.plot(loss_history)
plt.title('loss history')
# Out:
# Text(0.5, 1.0, 'loss history')

# %%
X_pred_test = model.predict(X_test)

X_pred_train = model.predict(X_train)

df_results_test = results_df(X_test,X_pred_test,y_test,y_rank_test,y_count_test)
df_results_train = results_df(X_train,X_pred_train,y_train,y_rank_train,y_count_train)

# %% [markdown]
# ## Assess errors for each time lag

# %%
res_train = df_results_train[df_results_train['y'] == 0]['residual_avg']

average_res_train = np.mean(res_train)
std_res_train = np.std(res_train)
threshold_3s = average_res_train + 3*std_res_train
threshold_5s = average_res_train + 5*std_res_train

threshold_list = [('3s',threshold_3s),('5s',threshold_5s)]

# %% [markdown]
# ### Training residuals

# %%
plt.figure()
sns.distplot(df_results_train['residual_avg'],norm_hist=True,kde=False,color='blue')
plt.xlim((0,1))
# Out:
# (0, 1)

# %%
for rank in range(1,np.max(df_results_test['y_rank'])+1):
    
    print('\n------------------ early time step of {}----------------------------'.format(rank))
    
    df_results_rank= df_results_test[(df_results_test['y_rank']==rank) | (df_results_test['y_rank']==0)]
    res_nominal_test = df_results_rank[df_results_rank['y'] == 0]['residual_avg']
    res_failures_test = df_results_rank[df_results_rank['y_rank'] == rank]['residual_avg']
    
    plt.figure()
    sns.distplot(res_failures_test,norm_hist=True,kde=False,color='red')
    sns.distplot(res_nominal_test,norm_hist=True,kde=False,color='blue')
    plt.legend(['failure residuals','non failure residuals'])
    plt.title('distribution of average residuals')

    y_true = np.array(df_results_rank['y'])
    y_pred_proba = np.array(df_results_rank['residual_avg']/np.max(df_results_rank['residual_avg']))

    plot_roc(y_true,y_pred_proba)
    
    for name,threshold in threshold_list:
        print('\n\n------ Using threshold {}---------------'.format(name))
        y_pred_threshold = np.where(df_results_rank['residual_avg'] > threshold, 1, 0)
        
        print('accuracy = {:.3f}'.format(accuracy_score(y_true,y_pred_threshold)))
        print('precision = {:.3f}'.format(precision_score(y_true,y_pred_threshold)))
        print('recall = {:.3f}'.format(recall_score(y_true,y_pred_threshold)))
        print('f1 = {:.3f}'.format(f1_score(y_true,y_pred_threshold)))
# Out:
# ------------------ early time step of 1----------------------------
# ------ Using threshold 3s---------------
# accuracy = 0.936
# precision = 0.479
# recall = 0.193
# f1 = 0.275
#
#
# ------ Using threshold 5s---------------
# accuracy = 0.943
# precision = 0.789
# recall = 0.126
# f1 = 0.217
#
# ------------------ early time step of 2----------------------------
# ------ Using threshold 3s---------------
# accuracy = 0.928
# precision = 0.286
# recall = 0.082
# f1 = 0.127
#
#
# ------ Using threshold 5s---------------
# accuracy = 0.937
# precision = 0.636
# recall = 0.057
# f1 = 0.105
#
# ------------------ early time step of 3----------------------------
# ------ Using threshold 3s---------------
# accuracy = 0.928
# precision = 0.324
# recall = 0.098
# f1 = 0.150
#
#
# ------ Using threshold 5s---------------
# accuracy = 0.936
# precision = 0.556
# recall = 0.041
# f1 = 0.076
#
# ------------------ early time step of 4----------------------------
# ------ Using threshold 3s---------------
# accuracy = 0.926
# precision = 0.242
# recall = 0.065
# f1 = 0.102
#
#
# ------ Using threshold 5s---------------
# accuracy = 0.936
# precision = 0.600
# recall = 0.048
# f1 = 0.090
#
# ------------------ early time step of 5----------------------------
# ------ Using threshold 3s---------------
# accuracy = 0.925
# precision = 0.219
# recall = 0.056
# f1 = 0.090
#
#
# ------ Using threshold 5s---------------
# accuracy = 0.935
# precision = 0.500
# recall = 0.032
# f1 = 0.061

# %%
sns.boxplot(x='y_rank',y='residual_avg',data=df_results_test)
plt.ylim((0,.75))
# Out:
# (0, 0.75)
