# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from keras.layers import Input,Dense, Dropout
from keras.models import Model,Sequential
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ### Link to Paper

# %% [markdown]
# https://arxiv.org/pdf/1809.10717.pdf

# %%
DATA_DIR = '/Users/PeterC/Documents/gt/practicum/autoencoders/data/'
DATA_DIR = '/Users/chenpete/Documents/ESP/practicum/autoencoders/data/'

# %%
df = pd.read_csv(DATA_DIR + 'paper_mill_rare_events.csv')
df['time'] = pd.to_datetime(df['time'])

# %%
df['y'].value_counts()
# Out:
# 0    18274
# 1      124
# Name: y, dtype: int64

# %% [markdown]
# ### Move Up Y label by an increment

# %%
early_step = 4
df['y_early'] = 0
df['y_rank'] = -1
df['y_count'] = np.nan

failure_count = 1
for i in range(df.shape[0]):
    if df.iloc[i]['y'] == 1:
        df.loc[i-early_step:i,'y_early'] = 1
        df.loc[i-early_step:i,'y_rank'] = np.arange(early_step,-1,-1)
        df.loc[i-early_step:i,'y_count'] = failure_count
        failure_count += 1

# %%
df['y_rank'].value_counts()
# Out:
# -1    17786
#  4      124
#  3      124
#  2      123
#  1      122
#  0      119
# Name: y_rank, dtype: int64

# %% [markdown]
# df['y_rank'] = np.nan
# df['y_count'] = np.nan
# failure_length= 10
# failure_count = 1
#
# for i in range(df.shape[0]):
#     if df.iloc[i]['y'] == 1:
#         df.loc[i-failure_length+1:i,'y'] = 1
#         df.loc[i-failure_length+1:i,'y_rank'] = np.arange(failure_length,0,-1)
#         df.loc[i-failure_length+1:i,'y_count'] = failure_count
#         failure_count += 1

# %% [markdown]
# # XGBoost Feature Importance

# %%
import xgboost 

x_cols = [
        'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
       'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19',
       'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29',
       'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39',
       'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49',
       'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58', 'x59',
       'x60','x61'
]
y_cols = ['y']
X = df[x_cols]
y = df[y_cols]
xgb = xgboost.XGBClassifier()
xgb.fit(X,y)
# Out:
# /Users/chenpete/Documents/code/DL/dlenv/lib/python3.7/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/chenpete/Documents/code/DL/dlenv/lib/python3.7/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
fig, ax = plt.subplots(figsize=(10,10))
xgboost.plot_importance(xgb, max_num_features=50, height=0.8, ax=ax)
plt.show()

# %% [markdown]
# ## Scale datasets with standard scaler

# %%
non_scale_cols = ['time','y_early','y_rank','y_count']

param_cols = ['x3','x2','x10','x9','x45','x38','x15','x6','x27','x56',
              'x29','x31','x5','x13','x41','x42','x50','x26','x44','x37']
param_cols = ['x3','x2','x10','x9','x45','x38','x15','x6','x27','x56']

sc = StandardScaler()
df_scaled = pd.DataFrame(data = sc.fit_transform(df[param_cols]),columns=param_cols)
df_scaled = pd.concat([df[non_scale_cols],df_scaled],axis=1)

# %%
df_scaled['y_rank'].value_counts()
# Out:
# -1    17786
#  4      124
#  3      124
#  2      123
#  1      122
#  0      119
# Name: y_rank, dtype: int64

# %% [markdown]
# ### Plot standard scaled

# %% [markdown]
# %%capture
# for col in param_cols:
#     plt.figure(figsize=(15,5))
#     plt.plot(df_scaled[col])
#     for val in list(df_scaled[df_scaled['y']==1].index):
#         plt.axvline(val,color='red',linewidth=.2)
#     plt.xticks(rotation=45)
#     plt.title(col)
#     plt.savefig(DATA_DIR +'plots/std_scaled_{}.png'.format(col))

# %%
X_nominal = df_scaled[df_scaled['y_early'] == 0][param_cols]
X_event = df_scaled[df_scaled['y_early'] == 1][param_cols]


y_nominal = df_scaled[df_scaled['y_early'] == 0]['y_early']
y_event = df_scaled[df_scaled['y_early'] == 1]['y_early']

y_rank_nominal = df_scaled[df_scaled['y_early'] == 0]['y_rank']
y_rank_event = df_scaled[df_scaled['y_early'] == 1]['y_rank']

y_count_nominal = df_scaled[df_scaled['y_count'].isna()]['y_count']
y_count_event = df_scaled[df_scaled['y_count'] >= 1]['y_count']

# %%
X_train, X_test, y_train, y_test,y_rank_train, y_rank_test,y_count_train, y_count_test = train_test_split(X_nominal, y_nominal, y_rank_nominal,y_count_nominal, test_size=0.1, random_state=0)

# %%
X_test = X_test.append(X_event)
y_test = y_test.append(y_event)
y_rank_test = y_rank_test.append(y_rank_event)
y_count_test = y_count_test.append(y_count_event)

# %%
def simple_ann_autoencoder_regression():
    model = Sequential()
    #model.add(Dense(units = 32,activation='relu',input_shape = (len(param_cols),)))
    model.add(Dense(units = 10,activation='relu',input_shape = (len(param_cols),)))
    model.add(Dense(units = 8,activation='relu',input_shape = (len(param_cols),)))
    model.add(Dense(units = 10,activation='relu',input_shape = (len(param_cols),)))
    #model.add(Dense(units = 32,activation='relu',input_shape = (len(param_cols),)))
    model.add(Dense(units = len(param_cols),activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
def results_df(X_true,X_pred,y_test,y_rank,y_count):
    residual = X_pred - X_true
    residual_avg = np.abs(np.mean(residual,axis=1))
    df = pd.DataFrame(data = {'residual_avg':residual_avg,
                              'y':y_test,
                              'y_rank':y_rank,
                              'y_count':y_count
                             }
                     )
    return df

def plot_results_hist(df_results):
    plt.figure()
    sns.distplot(df_results[df_results['y']==1]['residual_avg'],norm_hist=True)
    sns.distplot(df_results[df_results['y']==0]['residual_avg'],norm_hist=True)
    plt.legend(['event_residuals_avg','nominal_residuals_avg'])
    plt.title('distribution of average residuals')
    
def plot_results_violin(df_results):
    plt.figure()
    sns.violinplot(x='y',y='residual_avg',data=df_results)

# %% [markdown]
# # Model 1: Layer autoencoder - standard scaler (regression

# %%
model = simple_ann_autoencoder_regression()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                90
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                110
# =================================================================
# Total params: 398
# Trainable params: 398
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_callback = model.fit(X_train,X_train,epochs=75,batch_size = 12)
loss_history = history_callback.history['loss']
# Out:
# Epoch 1/75
# 16896/16896 [==============================] - 1s 72us/step - loss: 0.5145
# Epoch 2/75
# 16896/16896 [==============================] - 1s 57us/step - loss: 0.1941
# Epoch 3/75
# 16896/16896 [==============================] - 1s 57us/step - loss: 0.1320
# Epoch 4/75
# 16896/16896 [==============================] - 1s 57us/step - loss: 0.0993
# Epoch 5/75
# 16896/16896 [==============================] - 1s 58us/step - loss: 0.0833
# Epoch 6/75
# 16896/16896 [==============================] - 1s 57us/step - loss: 0.0719
# Epoch 7/75
# 16896/16896 [==============================] - 1s 57us/step - loss: 0.0663
# Epoch 8/75
# 16896/16896 [==============================] - 1s 62us/step - loss: 0.0605
# Epoch 9/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0568
# Epoch 10/75
# 16896/16896 [==============================] - 1s 62us/step - loss: 0.0521
# Epoch 11/75
# 16896/16896 [==============================] - 1s 62us/step - loss: 0.0482
# Epoch 12/75
# 16896/16896 [==============================] - 1s 62us/step - loss: 0.0436
# Epoch 13/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0405
# Epoch 14/75
# 16896/16896 [==============================] - 1s 64us/step - loss: 0.0374
# Epoch 15/75
# 16896/16896 [==============================] - 1s 63us/step - loss: 0.0351
# Epoch 16/75
# 16896/16896 [==============================] - 1s 65us/step - loss: 0.0336
# Epoch 17/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0331
# Epoch 18/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0323
# Epoch 19/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0320
# Epoch 20/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0314
# Epoch 21/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0314
# Epoch 22/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0309
# Epoch 23/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0307
# Epoch 24/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0311
# Epoch 25/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0309
# Epoch 26/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0304
# Epoch 27/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0305
# Epoch 28/75
# 16896/16896 [==============================] - 1s 65us/step - loss: 0.0303
# Epoch 29/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0307
# Epoch 30/75
# 16896/16896 [==============================] - 1s 71us/step - loss: 0.0302
# Epoch 31/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0299
# Epoch 32/75
# 16896/16896 [==============================] - 1s 72us/step - loss: 0.0299
# Epoch 33/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0303
# Epoch 34/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0302
# Epoch 35/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0305
# Epoch 36/75
# 16896/16896 [==============================] - 1s 65us/step - loss: 0.0299
# Epoch 37/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0301
# Epoch 38/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0300
# Epoch 39/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0302
# Epoch 40/75
# 16896/16896 [==============================] - 1s 73us/step - loss: 0.0299
# Epoch 41/75
# 16896/16896 [==============================] - 1s 72us/step - loss: 0.0302
# Epoch 42/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0301
# Epoch 43/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0298
# Epoch 44/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0298
# Epoch 45/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0295
# Epoch 46/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0299
# Epoch 47/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0298
# Epoch 48/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0300
# Epoch 49/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0297
# Epoch 50/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0299
# Epoch 51/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0300
# Epoch 52/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0296
# Epoch 53/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0295
# Epoch 54/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0297
# Epoch 55/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0301
# Epoch 56/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0296
# Epoch 57/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0299
# Epoch 58/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0294
# Epoch 59/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0298
# Epoch 60/75
# 16896/16896 [==============================] - 1s 71us/step - loss: 0.0298
# Epoch 61/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0296
# Epoch 62/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0298
# Epoch 63/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0297
# Epoch 64/75
# 16896/16896 [==============================] - 1s 67us/step - loss: 0.0299
# Epoch 65/75
# 16896/16896 [==============================] - 1s 68us/step - loss: 0.0291
# Epoch 66/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0298
# Epoch 67/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0295
# Epoch 68/75
# 16896/16896 [==============================] - 1s 71us/step - loss: 0.0292
# Epoch 69/75
# 16896/16896 [==============================] - 1s 71us/step - loss: 0.0294
# Epoch 70/75
# 16896/16896 [==============================] - 1s 71us/step - loss: 0.0296
# Epoch 71/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0295
# Epoch 72/75
# 16896/16896 [==============================] - 1s 72us/step - loss: 0.0295
# Epoch 73/75
# 16896/16896 [==============================] - 1s 69us/step - loss: 0.0295
# Epoch 74/75
# 16896/16896 [==============================] - 1s 66us/step - loss: 0.0298
# Epoch 75/75
# 16896/16896 [==============================] - 1s 70us/step - loss: 0.0297

# %%
plt.plot(loss_history)
plt.title('loss history')
# Out:
# Text(0.5, 1.0, 'loss history')

# %%
X_pred_test = model.predict(X_test)

# %%
X_pred_train = model.predict(X_train)

# %%
X_pred_test.shape
# Out:
# (1502, 10)

# %%
df_results_test = results_df(X_test,X_pred_test,y_test,y_rank_test,y_count_test)
df_results_train = results_df(X_train,X_pred_train,y_train,y_rank_train,y_count_train)

# %%
df_results_test['y_rank'].value_counts()
# Out:
# -1    890
#  4    124
#  3    124
#  2    123
#  1    122
#  0    119
# Name: y_rank, dtype: int64

# %% [markdown]
# ## Assess errors for each time lag

# %%
res_nominal_train = df_results_train[df_results_train['y'] == 0]['residual_avg']

average_res_nominal_train = np.mean(res_nominal_train)
std_res_nominal_train = np.std(res_nominal_train)
threshold_3s = average_res_nominal_train + 3*std_res_nominal_train
threshold_5s = average_res_nominal_train + 5*std_res_nominal_train

threshold_list = [('3s',threshold_3s),('5s',threshold_5s)]

# %% [markdown]
# ### Training residuals

# %%
plt.figure()
sns.distplot(df_results_train['residual_avg'],norm_hist=True,kde=False,color='blue')
plt.xlim((0,1))
# Out:
# (0, 1)

# %%
for rank in range(early_step+1):
    
    print('\n------------------ early time step of {}----------------------------'.format(rank+1))
    
    df_results_rank= df_results_test[(df_results_test['y_rank']==rank) | (df_results_test['y_rank']==-1)]
    
    plt.figure()
    sns.distplot(df_results_rank[df_results_rank['y_rank']==rank]['residual_avg'],norm_hist=True,kde=False,color='red')
    sns.distplot(df_results_rank[df_results_rank['y']==0]['residual_avg'],norm_hist=True,kde=False,color='blue')
    
    plt.legend(['failure residuals','non failure residuals'])
    plt.title('distribution of average residuals')

    y_true = np.array(df_results_rank['y'])
    y_pred = np.array(df_results_rank['residual_avg']/np.max(df_results_rank['residual_avg']))

    fpr, tpr, thresholds = roc_curve(y_true,y_pred)
    roc_auc = auc(fpr,tpr)

    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC for reconstruction error classification')
    plt.legend(loc="lower right")
    plt.show()
    
    
    res_nominal = df_results_rank[df_results_rank['y'] == 0]['residual_avg']
    res_event = df_results_rank[df_results_rank['y_rank'] == rank]['residual_avg']
    
    for name,threshold in threshold_list:
        print('------ Using threshold {}---------------'.format(name))
        TP = res_event[res_event>threshold].shape[0]
        FP = res_nominal[res_nominal>threshold].shape[0]
        TN = res_nominal[res_nominal<threshold].shape[0]
        FN = res_event[res_event<threshold].shape[0]

        total_nominal = TN + FP
        total_failure = TP + FN
        precision =TP/(TP+FP)
        recall = TP/(TP+FN)
        f1 = 2*(precision*recall)/(precision+recall)

        print('% of nominal accuracy with 3s threshold is {:.2%} = {}/{}'.format(TN/total_nominal,TN,total_nominal))
        print('% of failure accuracy with 3s threshold is {:.2%} = {}/{}'.format(TP/total_failure,TP,total_failure))

        print('precision = {:.3f}'.format(precision))
        print('recall = {:.3f}'.format(recall))
        print('f1 = {:.3f}'.format(f1))
# Out:
# ------------------ early time step of 1----------------------------
# ------ Using threshold 3s---------------
# % of nominal accuracy with 3s threshold is 99.21% = 883/890
# % of failure accuracy with 3s threshold is 10.92% = 13/119
# precision = 0.650
# recall = 0.109
# f1 = 0.187
# ------ Using threshold 5s---------------
# % of nominal accuracy with 3s threshold is 99.66% = 887/890
# % of failure accuracy with 3s threshold is 6.72% = 8/119
# precision = 0.727
# recall = 0.067
# f1 = 0.123
#
# ------------------ early time step of 2----------------------------
# ------ Using threshold 3s---------------
# % of nominal accuracy with 3s threshold is 99.21% = 883/890
# % of failure accuracy with 3s threshold is 5.74% = 7/122
# precision = 0.500
# recall = 0.057
# f1 = 0.103
# ------ Using threshold 5s---------------
# % of nominal accuracy with 3s threshold is 99.66% = 887/890
# % of failure accuracy with 3s threshold is 4.10% = 5/122
# precision = 0.625
# recall = 0.041
# f1 = 0.077
#
# ------------------ early time step of 3----------------------------
# ------ Using threshold 3s---------------
# % of nominal accuracy with 3s threshold is 99.21% = 883/890
# % of failure accuracy with 3s threshold is 6.50% = 8/123
# precision = 0.533
# recall = 0.065
# f1 = 0.116
# ------ Using threshold 5s---------------
# % of nominal accuracy with 3s threshold is 99.66% = 887/890
# % of failure accuracy with 3s threshold is 4.07% = 5/123
# precision = 0.625
# recall = 0.041
# f1 = 0.076
#
# ------------------ early time step of 4----------------------------
# ------ Using threshold 3s---------------
# % of nominal accuracy with 3s threshold is 99.21% = 883/890
# % of failure accuracy with 3s threshold is 4.84% = 6/124
# precision = 0.462
# recall = 0.048
# f1 = 0.088
# ------ Using threshold 5s---------------
# % of nominal accuracy with 3s threshold is 99.66% = 887/890
# % of failure accuracy with 3s threshold is 4.84% = 6/124
# precision = 0.667
# recall = 0.048
# f1 = 0.090
#
# ------------------ early time step of 5----------------------------
# ------ Using threshold 3s---------------
# % of nominal accuracy with 3s threshold is 99.21% = 883/890
# % of failure accuracy with 3s threshold is 4.03% = 5/124
# precision = 0.417
# recall = 0.040
# f1 = 0.074
# ------ Using threshold 5s---------------
# % of nominal accuracy with 3s threshold is 99.66% = 887/890
# % of failure accuracy with 3s threshold is 4.03% = 5/124
# precision = 0.625
# recall = 0.040
# f1 = 0.076

# %%
sns.boxplot(x='y_rank',y='residual_avg',data=df_results_test)
plt.ylim((0,.75))
# Out:
# (0, 0.75)

# %%
plt.figure()
plt.axhline(threshold_3s,linewidth = 4)
plt.ylim((0,.2))
failure_trigger = 0
for val in df_results_test['y_count'].unique():
    if val > 0:
        df_failure = df_results_test[df_results_test['y_count'] == val]
        plt.plot(df_failure['y_rank'],df_failure['residual_avg'],alpha=.1,color='red')

plt.xticks([0,1,2,3])
# Out:
# ([<matplotlib.axis.XTick at 0x1587d9320>,
#   <matplotlib.axis.XTick at 0x1587dbcc0>,
#   <matplotlib.axis.XTick at 0x1587db908>,
#   <matplotlib.axis.XTick at 0x158973ba8>],
#  <a list of 4 Text xticklabel objects>)
